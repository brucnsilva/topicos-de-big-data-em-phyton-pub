# %% [markdown]
# <a href="https://colab.research.google.com/github/brunachavesn/topicos-de-big-data-em-phyton-pub/blob/main/teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# %%
print("Selecione o arquivo BaseMunicipioMensal.csv:")
uploaded = files.upload()
# Out:
# Selecione o arquivo BaseMunicipioMensal.csv:
#      <input type="file" id="files-0c9f52a7-0c3f-40d3-99f5-3f5533fcfba7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c9f52a7-0c3f-40d3-99f5-3f5533fcfba7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
df = pd.read_csv('BaseMunicipioMensal.csv', sep=';', encoding='latin-1')

# %%
colunas_desejadas = [
    'fmun',
    'ano',
    'mes',
    'regiao',
    'roubo_veiculo',
    'furto_veiculos',
    'trafico_drogas',
    'recuperacao_veiculos'
]

# %%
df_filtrado = df[colunas_desejadas]

# %%
print("\nPlanilha filtrada base municipal")
display(df_filtrado.head())
# Out:
# Planilha filtrada base municipal
#                  fmun   ano  mes    regiao  roubo_veiculo  furto_veiculos  \
# 0      Angra dos Reis  2014    1  Interior              8              18
# 1             Aperibé  2014    1  Interior              0               0
# 2            Araruama  2014    1  Interior              9              16
# 3               Areal  2014    1  Interior              0               0
# 4  Armação dos Búzios  2014    1  Interior              2               9
#
#    trafico_drogas  recuperacao_veiculos
# 0              12                     9
# 1               0                     0
# 2               4                     4
# 3               0                     0
# 4              10                     2

# %%
df_filtrado.to_csv('planilha_filtrada.csv', index=False, sep=';', encoding='utf-8-sig')
files.download('planilha_filtrada.csv')
